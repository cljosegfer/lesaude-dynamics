# %% [markdown]
# # setup

# %%
import numpy as np
import h5py

# %%
H5_WAVEFORMS = '/home/remote/Documents/datasets/lesaude/mimic-iv-ecg-monolith/mimic_iv_ecg_waveforms.h5'
H5_ICD = '/home/remote/Documents/datasets/lesaude/mimic-iv-ecg-monolith/mimic_iv_ecg_icd.h5'

# %% [markdown]
# # verify

# %%
with h5py.File(H5_WAVEFORMS, 'r') as f:
    x_subjects = f['subject_id'][:]
    x_studies = f['study_id'][:]

# %%
with h5py.File(H5_ICD, 'r') as f:
    y_subjects = f['subject_id'][:]
    y_studies = f['study_id'][:]
    vocabulary = f['vocabulary'][:]

# %%
np.where(x_studies != y_studies), np.where(x_subjects != y_subjects)
# Out:
# ((array([], dtype=int64),), (array([], dtype=int64),))

# %%
len(vocabulary), vocabulary
# Out:
# (76,
#  array([b'I00', b'I01', b'I05', b'I06', b'I07', b'I08', b'I09', b'I10',
#         b'I11', b'I12', b'I13', b'I15', b'I16', b'I20', b'I21', b'I22',
#         b'I23', b'I24', b'I25', b'I26', b'I27', b'I28', b'I30', b'I31',
#         b'I32', b'I33', b'I34', b'I35', b'I36', b'I37', b'I38', b'I39',
#         b'I40', b'I41', b'I42', b'I43', b'I44', b'I45', b'I46', b'I47',
#         b'I48', b'I49', b'I50', b'I51', b'I60', b'I61', b'I62', b'I63',
#         b'I65', b'I66', b'I67', b'I68', b'I69', b'I70', b'I71', b'I72',
#         b'I73', b'I74', b'I75', b'I76', b'I77', b'I78', b'I79', b'I80',
#         b'I81', b'I82', b'I83', b'I85', b'I86', b'I87', b'I88', b'I89',
#         b'I95', b'I96', b'I97', b'I99'], dtype=object))
